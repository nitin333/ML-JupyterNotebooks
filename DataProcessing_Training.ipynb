# %%
import pandas as pd

# %%
df = pd.read_csv('credit_card_churn.csv')

# %%
df.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# ...

# %%
import cx_Oracle   #  pip install cx_Oracle
from sqlalchemy import create_engine

engine = create_engine('oracle+cx_oracle://xxxxx:xxxxx@host:1521/?service_name=hr')

df = pd.read_sql('select * from table_name', engine)

# %%
import teradatasql
import pandas as pd
with teradatasql.connect(host='your_host_name', user='your_user_name', password='*******') as connect:
     df = pd.read_sql('select * from your_table_name;', connect)
print(df.head())

# %%
#Datetime string to date
df['Date']= pd.to_datetime(df['Date'])

# convert the 'Date' column to datetime format
df['Date'] = df['Date'].astype('datetime64[ns]')

# converting the string to datetime format
df['Dates'] = pd.to_datetime(df['Dates'], format='%y%m%d')
df['Treatment_date'] = pd.to_datetime(df['Treatment_date'],format='%Y%m%d')

# %%
#Datetime to Date
df['date_column'].map(lambda x: x.strftime('%Y-%m-%d'))
df['mnth_yr'] = df['date_column'].apply(lambda x: x.strftime('%B-%Y')) 
df['yyyy-mm'] = pd.to_datetime(df['ArrivalDate']).dt.strftime('%Y-%m')

# %%
# filter by single day
df[df["Date"].dt.strftime("%Y-%m-%d") == "2017-03-01"]

# filter by single month
df[df["Date"].dt.strftime("%m") == "12"]

# filter by single year
df[df["Date"].dt.strftime("%Y") == "2017"]

# filter between two dates
df[(df["Date"] > "2015-01-01") & (df["Date"] < "2017-01-01")]

# %%
### loc
df1 = df.loc[df[‘gender’]==’female’]
df1 = df.loc[(df['gender']=='male') & (df['Embarked']=='S')].head()
# select few columns with a condition
df1 = df.loc[(df.age >= 12), ['city', 'gender']]

# %%
### iloc
df1 = df.iloc[0:4,2:5]
df1 = df.iloc[[0,2],[1,3]]

# %%
### Groupby
df.groupby(['month', 'item',as_index = False])['c1'].count()
df.groupby(['month',as_index = False]).agg({'c1':'sum'})
df.groupby(['c1','c2']).agg({'c3':'sum','c4':'count','c5':'first'})

# %%
### group by examples.....renaming

df.groupby(['c1', 'c2']).agg({ 'c3': [min, max, sum],
        'c4': "count",'c5': [min, 'first', 'nunique']})

avg_sal = df.groupby(by = ['c1'], as_index = False).agg
({'c2' : 'mean'}).rename(columns = {'c2' : 'average_c2'})

df_1 = df[df['c1'].isin([2017, 2018])].groupby(by = ['c2'], as_index = False).agg(
        {'money_spent' : 'sum', 'customers_acquired':'sum'})

# %%
### Rank (c1 is dimension & c2 is numeric)
df['rank'] = df.groupby(['c1'])['c2'].rank(method='dense',ascending=False)

# %%
### cut & qcut
df['nums_labels'] = pd.cut(x=df['num'], bins=[1, 10, 20], labels=['Lows', 'Highs'], right=False)
df['decile'] = pd.qcut(df['c'],10,labels=False)

# %%
### Pivot
df1 = pd.pivot_table(df, index = 'c1',values = 'c2', columns= 'c3',fill_value= 0,aggfunc= np.sum)

# %%
### Joins
df1.merge(df2, left_on = 'ID1', right_on = 'ID2')

# %%
new_df = pd.merge(df1, df2,  how='left', left_on=['df1_c1','df1_c2'], right_on = ['df2_c1','df2_c2'])

# %%
# Using Index as the Join Keys for Merging DataFrames
df_merged = df1.merge(df2, left_index=True, right_index=True)

# %%
# importing pandas
import pandas as pd
  
# Creating dataframe a
a = pd.DataFrame()
  
# Creating Dictionary
b = {'id': [1, 2, 10, 12],
     'val1': ['a', 'b', 'c', 'd']}
  
a = pd.DataFrame(b)
  
# Creating dataframe b
c = pd.DataFrame()
  
# Creating dictionary
c = {'id': [1, 2, 9, 8],
     'val1': ['p', 'q', 'r', 's']}
d = pd.DataFrame(c)

# %%
a
# Out:
#    id val1
# 0   1    a
# 1   2    b
# 2  10    c
# 3  12    d

# %%
d
# Out:
#    id val1
# 0   1    p
# 1   2    q
# 2   9    r
# 3   8    s

# %%
# inner join
df1 = pd.merge(a, d, on='id', how='inner')

# %%
df1
# Out:
#    id val1_x val1_y
# 0   1      a      p
# 1   2      b      q

# %%
df2 = pd.merge(a, d, on='id', how='left')

# %%
df2
# Out:
#    id val1_x val1_y
# 0   1      a      p
# 1   2      b      q
# 2  10      c    NaN
# 3  12      d    NaN

# %%
# right outer join
df3 = pd.merge(a, d, on='id', how='right')

# %%
df3
# Out:
#    id val1_x val1_y
# 0   1      a      p
# 1   2      b      q
# 2   9    NaN      r
# 3   8    NaN      s

# %%
# full outer join
df4 = pd.merge(a, d, on='id', how='outer')

# %%
df4
# Out:
#    id val1_x val1_y
# 0   1      a      p
# 1   2      b      q
# 2  10      c    NaN
# 3  12      d    NaN
# 4   9    NaN      r
# 5   8    NaN      s

# %%
# index join
df5 = pd.merge(a, d, left_index=True, right_index=True)

# %%
df5
# Out:
#    id_x val1_x  id_y val1_y
# 0     1      a     1      p
# 1     2      b     2      q
# 2    10      c     9      r
# 3    12      d     8      s

# %%
### sorting
df.sort_values(by = ['c1', 'c2'], ascending = [False, True])

# %%
### Missing Value
df['salary'] = df['salary'].fillna(df['salary'].mode()[0])
df['salary'] = df['salary'].fillna(df['salary'].mode().iloc[0])

# %%
### Creating dummies with np.where

dataset['NewYork_State'] = np.where(dataset['State']=='New York', 1, 0)
dataset['California_State'] = np.where(dataset['State']=='California', 1, 0)
dataset['Florida_State'] = np.where(dataset['State']=='Florida', 1, 0)

# %%
### Crosstab

# %%
pd.crosstab(df.Gender, df.Education_Level)

# %%
df.groupby(['Gender', 'Education_Level'])['Education_Level'].count().unstack().fillna(0)

# %%
pd.crosstab(df.Gender, df.Education_Level, values=df.Credit_Limit, aggfunc='mean').round(0)
# Out:
# Education_Level  College  Doctorate  Graduate  High School  Post-Graduate  \
# Gender
# F                 4775.0     5379.0    5011.0       5132.0         4719.0
# M                13008.0    12433.0   12638.0      12231.0        13170.0
#
# Education_Level  Uneducated  Unknown
# Gender
# F                    5150.0   4938.0
# M                   13218.0  12574.0

# %%
### Pivot
import numpy as np
df1 = pd.pivot_table(df, index = 'Gender',values = 'Credit_Limit', columns= 'Education_Level',fill_value= 0,aggfunc= np.mean).round(0)

# %%
df1
# Out:
# Education_Level  College  Doctorate  Graduate  High School  Post-Graduate  \
# Gender
# F                 4775.0     5379.0    5011.0       5132.0         4719.0
# M                13008.0    12433.0   12638.0      12231.0        13170.0
#
# Education_Level  Uneducated  Unknown
# Gender
# F                    5150.0   4938.0
# M                   13218.0  12574.0

# %%
### Map
atrr_flag = {'Existing Customer':0,'Attrited Customer':1}

# %%
df['Attrition_Flag'] = df['Attrition_Flag'].map(atrr_flag)

# %%
### Apply
data = pd.DataFrame({'EmployeeName': ['Callen Dunkley', 'Sarah Rayner', 'Jeanette Sloan', 'Kaycee Acosta', 'Henri Conroy', 'Emma Peralta', 'Martin Butt', 'Alex Jensen', 'Kim Howarth', 'Jane Burnett'],
                    'Department': ['Accounting', 'Engineering', 'Engineering', 'HR', 'HR', 'HR', 'Data Science', 'Data Science', 'Accounting', 'Data Science'],
                    'HireDate': [2010, 2018, 2012, 2014, 2014, 2018, 2020, 2018, 2020, 2012],
                    'Sex': ['M', 'F', 'F', 'F', 'M', 'F', 'M', 'M', 'M', 'F'],
                    'Birthdate': ['04/09/1982', '14/04/1981', '06/05/1997', '08/01/1986', '10/10/1988', '12/11/1992', '10/04/1991', '16/07/1995', '08/10/1992', '11/10/1979'],
                    'Weight': [78, 80, 66, 67, 90, 57, 115, 87, 95, 57],
                    'Height': [176, 160, 169, 157, 185, 164, 195, 180, 174, 165],
                    'Kids': [2, 1, 0, 1, 1, 0, 2, 0, 3, 1]
                    })

# %%
data['FirstName'] = data['EmployeeName'].apply(lambda x : x.split()[0])
data['LastName'] = data['EmployeeName'].apply(lambda x : x.split()[1])

# %%
data.head()
# Out:
#      EmployeeName   Department  HireDate Sex   Birthdate  Weight  Height  Kids
# 0  Callen Dunkley   Accounting      2010   M  04/09/1982      78     176     2
# 1    Sarah Rayner  Engineering      2018   F  14/04/1981      80     160     1
# 2  Jeanette Sloan  Engineering      2012   F  06/05/1997      66     169     0
# 3   Kaycee Acosta           HR      2014   F  08/01/1986      67     157     1
# 4    Henri Conroy           HR      2014   M  10/10/1988      90     185     1

# %%
from datetime import datetime, date

def calculate_age(birthdate):
    birthdate = datetime.strptime(birthdate, '%d/%m/%Y').date()
    today = date.today()
    return today.year - birthdate.year - (today.month < birthdate.month)

# %%
data['Age'] = data['Birthdate'].apply(calculate_age)

# %%
def age_bucket(age):
    if age < 35:
        return "< 35"
    elif  35 <= age <= 40 :
        return "35-40"
    else:
        return ">40"

# %%
data["age_band"] = data["Age"].apply(lambda Age: age_bucket(Age))

# %%
### Replace
# will replace Nan value in dataframe with value -99999
df.replace(to_replace = np.nan, value =-99999)
data.replace(to_replace=["Engineering", "Accounting"],
           value=['Eng','Acct'])
# Out:
#      EmployeeName    Department  HireDate Sex   Birthdate  Weight  Height  \
# 0  Callen Dunkley          Acct      2010   M  04/09/1982      78     176
# 1    Sarah Rayner           Eng      2018   F  14/04/1981      80     160
# 2  Jeanette Sloan           Eng      2012   F  06/05/1997      66     169
# 3   Kaycee Acosta            HR      2014   F  08/01/1986      67     157
# 4    Henri Conroy            HR      2014   M  10/10/1988      90     185
# 5    Emma Peralta            HR      2018   F  12/11/1992      57     164
# 6     Martin Butt  Data Science      2020   M  10/04/1991     115     195
# 7     Alex Jensen  Data Science      2018   M  16/07/1995      87     180
# 8     Kim Howarth          Acct      2020   M  08/10/1992      95     174
# 9    Jane Burnett  Data Science      2012   F  11/10/1979      57     165
#
#    Kids FirstName LastName  Age age_band
# 0     2    Callen  Dunkley   40    35-40
# 1     1     Sarah   Rayner   41      >40
# ...

# %%
data['EmployeeName'].replace('E','e',regex=True, inplace = True)

# %%
data[data['EmployeeName'].str.match('^Ka.*')== True]
# Out:
#     EmployeeName Department  HireDate Sex   Birthdate  Weight  Height  Kids  \
# 3  Kaycee Acosta         HR      2014   F  08/01/1986      67     157     1
#
#   FirstName LastName  Age age_band
# 3    Kaycee   Acosta   37    35-40

# %%
[itm[0] for itm in data['EmployeeName'].str.findall('^[H].*') if len(itm)>0]
# Out:
# ['Henri Conroy']

# %%
data['EmployeeName'].str.contains('^Ka.*')
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# Name: EmployeeName, dtype: bool

# %%
ss = """Nory was a Catholic because her mother was a Catholic, 
and Nory's mother was a Catholic because her father was a Catholic, 
and her father was a Catholic because his mother was a Catholic, 
or had been."""

# %%
words = ss.split()

d = {x:0 for x in words}

for w in words:
    d[w] += 1
print (d)
# Out:
# {'Nory': 1, 'was': 6, 'a': 6, 'Catholic': 3, 'because': 3, 'her': 3, 'mother': 3, 'Catholic,': 3, 'and': 2, "Nory's": 1, 'father': 2, 'his': 1, 'or': 1, 'had': 1, 'been.': 1}

# %%
ds = sorted(d.items(), key = lambda x:x[1], reverse = True)

# %%
ds
# Out:
# [('was', 6),
#  ('a', 6),
#  ('Catholic', 3),
#  ('because', 3),
#  ('her', 3),
#  ('mother', 3),
#  ('Catholic,', 3),
#  ('and', 2),
#  ('father', 2),
#  ('Nory', 1),
#  ("Nory's", 1),
#  ('his', 1),
#  ('or', 1),
#  ('had', 1),
#  ('been.', 1)]
